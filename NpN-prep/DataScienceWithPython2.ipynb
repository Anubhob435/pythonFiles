# %%
import pandas as pd

data = pd.read_csv('Data/employees_data.csv', skiprows=8)

data.shape

data.head()
# Out:
#    E1031 Aadhya Sharma Human Resources     Training Specialist     Mumbai  \
# 0  E1032   Arjun Patel              IT   Cybersecurity Analyst      Delhi
# 1  E1033   Kavya Singh       Marketing           Brand Manager  Bangalore
# 2  E1034   Dhruv Reddy         Finance          Budget Analyst  Hyderabad
# 3  E1035    Riya Gupta           Sales  Regional Sales Manager    Kolkata
# 4  E1036    Atharv Das     Engineering       Backend Developer     Mumbai
#
#    2023-03-15   67000  4
# 0  2022-08-22   95000  5
# 1  2021-10-12   87000  4
# 2  2024-02-18   71000  3
# 3  2020-05-30  112000  5
# 4  2023-06-25  102000  4

# %%
import glob

for directory in glob.glob("session1/*"):
    print(directory)

data_frame = []

for directory in glob.glob("session1/*"):
    for file in glob.glob(directory + "/*.csv"):
        df = pd.read_csv(file)
        data_frame.append(df)
        
print(data_frame)
# Out:
# session1\mysql-sample-database.png
# session1\mySQLlogics.py
# session1\PowerBi_Sample_Data
# session1\quary.sql
# session1\session1-Part1.txt
# session1\session1-part2.txt
# session1\SQL_Database_sample
# session1\test.drawio
# [   EmployeeID           FullName       Department                  JobTitle  \
# 0       E1001       Aarav Sharma            Sales           Sales Associate
# 1       E1002       Saanvi Patel        Marketing     Marketing Coordinator
# 2       E1003       Vikram Singh      Engineering         Software Engineer
# 3       E1004       Ananya Reddy  Human Resources             HR Generalist
# 4       E1005        Rohan Gupta               IT     IT Support Specialist
# 5       E1006           Diya Das          Finance         Financial Analyst
# 6       E1007        Arjun Kumar            Sales         Account Executive
# 7       E1008       Ishaan Joshi      Engineering           DevOps Engineer
# ...
